# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# # Dataset
# https://insights.stackoverflow.com/survey

# %%
results_df = pd.read_csv("stack-overflow-developer-survey-2023/survey_results_public.csv", index_col='ResponseId')
schema_df = pd.read_csv("stack-overflow-developer-survey-2023/survey_results_schema.csv", index_col='qname')

# %%
# check the question corresponding to the column name
# survey_results_schema & survey_results_public has some different question name
schema_df.loc['TimeSearching', 'question']
# Out:
# 'On an average day, how much time do you typically spend searching for answers or solutions to problems you encounter at work? (This includes time spent searching on your own, asking a colleague, and waiting for a response).'

# %% [markdown]
# ## Feedback

# %% [markdown]
# ### How do you feel about the length of the survey this year?
# https://survey.stackoverflow.co/2023/#how-do-you-feel-about-the-length-of-the-survey-this-year

# %%
fig, ax = plt.subplots()

bars = ax.barh(results_df['SurveyLength'].value_counts().index, results_df['SurveyLength'].value_counts().values)
ax.bar_label(bars)
ax
# Out:
# <Axes: >

# %% [markdown]
# ### How easy or difficult was this survey to complete?
# https://survey.stackoverflow.co/2023/#how-easy-or-difficult-was-this-survey-to-complete

# %%
fig, ax = plt.subplots()

bars = ax.barh(results_df['SurveyEase'].value_counts().index, results_df['SurveyEase'].value_counts().values)
ax.bar_label(bars)
ax
# Out:
# <Axes: >

# %% [markdown]
# ## Participants

# %% [markdown]
# ### Who participated in this survey
# https://survey.stackoverflow.co/2023/#who-participated-in-this-survey

# %%
fig, ax = plt.subplots()

bars = ax.barh(results_df['MainBranch'].value_counts().index, results_df['MainBranch'].value_counts().values)
ax.bar_label(bars)
ax
# Out:
# <Axes: >
